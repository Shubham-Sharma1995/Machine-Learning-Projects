# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubham33320/project/blob/main/decision_tree_classification(GRIP).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task 6 - Graduate Rotational Internship Program (GRIP - May 2021) organised by The Sparks Foundation**
#
# ## Aim: feed any new data to this classifier and predict the right class accordingly.
#
# ## Author : Shubham Sharma (Intern - May 2021)
# ## Question: Create a decision tree classifier and visualize it graphically

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Iris.csv')
X = dataset.iloc[:,[1,4]].values
y = dataset.iloc[:, -1].values
dataset.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.30, random_state = 1)

# %%
print("shape of the training data", X_train.shape)
# Out:
# shape of the training data (105, 2)

# %%
print("shape of the training data", X_test.shape)
# Out:
# shape of the training data (45, 2)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Training the Decision Tree Classification model on the Training set

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy',random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %% [markdown]
# ## Predicting a new result

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# ## Making the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[14  0  0]
#  [ 0 17  1]
#  [ 0  1 12]]
# 0.9555555555555556

# %%
print(classification_report(y_test, y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        14
# Iris-versicolor       0.94      0.94      0.94        18
#  Iris-virginica       0.92      0.92      0.92        13
#
#        accuracy                           0.96        45
#       macro avg       0.96      0.96      0.96        45
#    weighted avg       0.96      0.96      0.96        45

# %% [markdown]
# ## Plotting the confusion matrix

# %%
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(classifier,
                     X_test,
                     y_test)

# %% [markdown]
# ## Visualising the Decision Tree results

# %%
from sklearn.tree import plot_tree
from sklearn import tree
plt.figure(figsize=(30,20))
plot_tree(classifier,
         filled=True,
         rounded=True,
         class_names=['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'],feature_names= ['SepalLengthCm','SepalWidthCm' , 'PetalLengthCm' , 'PetalWidthCm']
        )
# Out:
# [Text(760.909090909091, 1026.8, 'SepalWidthCm <= -0.499\nentropy = 1.582\nsamples = 105\nvalue = [36, 32, 37]\nclass = Iris-virginica'),
#  Text(608.7272727272727, 906.0, 'entropy = 0.0\nsamples = 36\nvalue = [36, 0, 0]\nclass = Iris-setosa'),
#  Text(913.0909090909091, 906.0, 'SepalWidthCm <= 0.59\nentropy = 0.996\nsamples = 69\nvalue = [0, 32, 37]\nclass = Iris-virginica'),
#  Text(456.54545454545456, 785.2, 'SepalLengthCm <= 0.297\nentropy = 0.431\nsamples = 34\nvalue = [0, 31, 3]\nclass = Iris-versicolor'),
#  Text(304.3636363636364, 664.4, 'entropy = 0.0\nsamples = 19\nvalue = [0, 19, 0]\nclass = Iris-versicolor'),
#  Text(608.7272727272727, 664.4, 'SepalLengthCm <= 1.547\nentropy = 0.722\nsamples = 15\nvalue = [0, 12, 3]\nclass = Iris-versicolor'),
#  Text(456.54545454545456, 543.6, 'SepalLengthCm <= 0.654\nentropy = 0.592\nsamples = 14\nvalue = [0, 12, 2]\nclass = Iris-versicolor'),
# ...
